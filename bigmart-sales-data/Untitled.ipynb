# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('Train.csv')
test = pd.read_csv('Test.csv')

# %%
mean_sales = train['Item_Outlet_Sales'].mean()
# Out:
# 2181.288913575032

# %%
base1 = test[['Item_Identifier', 'Outlet_Identifier']]

base1['Item_Outlet_Sales']
# Out:
#      Item_Identifier Outlet_Identifier
# 0              FDW58            OUT049
# 1              FDW14            OUT017
# 2              NCN55            OUT010
# 3              FDQ58            OUT017
# 4              FDY38            OUT027
# 5              FDH56            OUT046
# 6              FDL48            OUT018
# 7              FDC48            OUT027
# 8              FDN33            OUT045
# 9              FDA36            OUT017
# 10             FDT44            OUT017
# 11             FDQ56            OUT045
# 12             NCC54            OUT019
# 13             FDU11            OUT049
# 14             DRL59            OUT013
# 15             FDM24            OUT049
# 16             FDI57            OUT045
# 17             DRC12            OUT018
# 18             NCM42            OUT027
# 19             FDA46            OUT010
# 20             FDA31            OUT013
# 21             NCJ31            OUT035
# 22             FDG52            OUT046
# ...
